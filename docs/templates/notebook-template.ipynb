# %% [markdown]
# # 🧠 [Project Name] - [Short Description]
#
# > **Version X.Y.Z** - [What's new in this version]
#
# [1-2 sentences describing what this notebook demonstrates]
#
# **Quick Links:**
# - [README](../README.md)
# - [ADR](link-to-relevant-adr)
# - [Service](https://service-url-if-applicable)

# %% [markdown]
# ## 🔧 Setup

# %%
# Colab Setup (uncomment if running in Colab)
# !pip install -q package-name

# Or clone repo
# !git clone https://github.com/org/repo.git
# %cd repo
# !pip install -e .

# %%
# Core imports
from package import MainClass

# Optional: Set environment variables
import os
# os.environ['API_KEY'] = 'your-key-here'  # Never commit real keys!

print("✅ Setup complete")

# %% [markdown]
# ---
#
# ## 🚀 Quick Start
#
# The fastest way to get started with [Project]. Copy-paste ready!

# %%
# Minimal working example
instance = MainClass.create_default()

result = instance.do_something(input_data)

print(f"Result: {result}")

# Expected output:
# Result: <expected value>

# %% [markdown]
# ### 📊 Understanding the Output
#
# [Explain what the output means, what the user should look for]

# %% [markdown]
# ---
#
# ## 📚 Deep Dive
#
# The sections below explore each component in detail.

# %% [markdown]
# ### Component 1: [Name]
#
# [Description of what this component does]

# %%
# Demonstrate Component 1
# ...

# %% [markdown]
# ### Component 2: [Name]
#
# [Description of what this component does]

# %%
# Demonstrate Component 2
# ...

# %% [markdown]
# ---
#
# ## 📊 API Reference
#
# ### MainClass
#
# | Method | Description | Returns |
# |--------|-------------|--------|
# | `create_default()` | Factory with defaults | `MainClass` |
# | `do_something(input)` | Process input | `Result` |
# | `get_stats()` | Current statistics | `Dict` |
#
# ### Result Object
#
# | Field | Type | Description |
# |-------|------|-------------|
# | `value` | `str` | The result value |
# | `confidence` | `float` | Confidence (0-1) |
# | `metadata` | `Dict` | Additional info |

# %% [markdown]
# ---
#
# ## 🔗 Related Resources
#
# ### Documentation
# - [Project README](../README.md)
# - [API Documentation](link)
# - [Architecture Decision Record](link-to-adr)
#
# ### Issues & Tracking
# - [Epic #XX](link)
# - [Issue #YY](link)
#
# ### External
# - [Relevant Paper](link)
# - [Library Documentation](link)

# %% [markdown]
# ---
#
# ## 📝 Changelog
#
# | Version | Date | Changes |
# |---------|------|--------|
# | 0.1.0 | YYYY-MM-DD | Initial version |
# | 0.2.0 | YYYY-MM-DD | Added feature X |
